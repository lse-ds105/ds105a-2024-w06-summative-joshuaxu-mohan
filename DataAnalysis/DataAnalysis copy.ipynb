# %% [markdown]
# **OBJECTIVE:** Analyse collected data of London and other cities
#
# **AUTHOR:** Joshua Xu
#
# **LAST EDITED:** 2024-10-25
#
# ---

# %% [markdown]
# # Data Analysis

# %% [markdown]
# In this notebook, I will be using the data I have collected to conduct some exploratory data anlaysis, primarily using the panda module.

# %%
import json
import requests
import pandas as pd
import matplotlib

# %% [markdown]
# ## 1. Exploration

# %% [markdown]
# We begin by converting our data in a data frame to have a better understanding of our given data:

# %%
with open('../Data/all_data.json') as file:
    data = json.load(file)

df = pd.DataFrame(data)
df.head()
# Out:
#    London  Porto Novo  Kigali  Apia  Tiraspol  Dublin  Ljubljana  Kuwait City  \
# 0     4.0         0.0     0.0   2.2       0.0     1.3        0.0          0.0
# 1     0.2         0.0     0.0   9.8       0.0     0.0        0.0          0.0
# 2     3.2         0.0     0.1   8.3       0.0    16.7        0.1          0.0
# 3     0.9         0.0     1.5  22.2       0.0     0.2        0.2         10.5
# 4     0.1         0.0     2.7  44.8       0.3     4.9        0.0          0.0
#
#    Bangkok  Santo Domingo  Brasiléia
# 0      0.0            1.8       10.1
# 1      0.0            2.2        0.1
# 2      0.0            1.5        0.8
# 3      0.0            0.1       11.4
# 4      0.0           11.2       27.0

# %%
df.plot()
# Out:
# <Axes: >
